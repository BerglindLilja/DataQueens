# %% [markdown]
# # Part I - Binning degree distributions

# %%
import matplotlib.pyplot as plt
import numpy as np
import random as rd
import networkx as nx

# %% [markdown]
# ### Binning real numbers

# %%
arr = np.empty(5000, dtype = float)

for i in range(5000):
    arr[i] = rd.gauss(2,0.125)
    
# np.histogram(arr, bins=10)


plt.hist(arr, bins=10) 
plt.show()

# %% [markdown]
# ###### You will have to deal with the fact that the counts- and bin-arrays have different lengths. Explain how you deal with this problem and why.

# %% [markdown]
# We deal with this...

# %% [markdown]
# ### Binning integers

# %%
numbers = np.random.poisson(10, 5000)
maxN = max(numbers)
minN = min(numbers)

print(minN, maxN)
# Out:
# 0 23

# %%
binsize = np.linspace(minN, maxN, 11)
print(binsize)
# Out:
# [ 0.   2.3  4.6  6.9  9.2 11.5 13.8 16.1 18.4 20.7 23. ]

# %%
# histo = np.histogram(numbers, binsize)
counts, binsize = np.histogram(numbers)
print(histo)
# Out:
# (array([  12,  312,  825, 1781, 1013,  808,  207,   29,   11,    2]), array([ 0. ,  2.6,  5.2,  7.8, 10.4, 13. , 15.6, 18.2, 20.8, 23.4, 26. ]))

# %%
plt.hist(binsize[:-1], binsize, weights=counts)
plt.xlabel("Bins")
plt.ylabel("# of numbers in each bin")
plt.show()

# %% [markdown]
# What is the sum over bin counts?

# %% [markdown]
# Explain how the binning-vectors first and last element relates to the min and max from the Poisson distribution.

# %% [markdown]
# ### Binning and plotting degree distributions

# %%
N = 5000
k = 10
p = k/(N-1)
print(p)
# Out:
# 0.002000400080016003

# %%
g = nx.erdos_renyi_graph(N,p)

nx.draw_shell(g)

# %%
def plot_degree_dist(G):
    degrees = [G.degree(n) for n in G.nodes()]
    plt.hist(degrees)
    plt.show()
    
# naming the x axis
plt.xlabel('Degree distribution')

# naming the y axis
plt.ylabel('# of numbers in each bin')
 
# graph title
plt.title('Erdös-Renyi network graph')

plot_degree_dist(g)
